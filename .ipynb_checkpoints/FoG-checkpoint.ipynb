# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %%
data=pd.read_csv('/home/pelto/Downloads/DOI-WGMS-FoG-2019-12/WGMS-FoG-2019-12-EE-MASS-BALANCE.csv')

# %%
OV=pd.read_csv('/home/pelto/Downloads/DOI-WGMS-FoG-2019-12/WGMS-FoG-2019-12-E-MASS-BALANCE-OVERVIEW.csv')

# %%
CAN=OV[OV.POLITICAL_UNIT=='CA']
CAN
# Out:
#      POLITICAL_UNIT                               NAME  WGMS_ID  Year  \
# 866              CA                            ABRAHAM       48  1982
# 867              CA                            ABRAHAM       48  1983
# 868              CA                            ABRAHAM       48  1984
# 869              CA                          ALEXANDER       32  1979
# 870              CA                          ALEXANDER       32  1980
# 871              CA                          ALEXANDER       32  1981
# 872              CA                          ALEXANDER       32  1982
# 873              CA                          ALEXANDER       32  1983
# 874              CA                          ALEXANDER       32  1984
# 875              CA                          ALEXANDER       32  1985
# 876              CA                          ALEXANDER       32  1989
# 877              CA                          ALEXANDER       32  1990
# ...

# %%
OV=OV[OV.Year>2012]
OV.MAX_SITES_ACC[OV.MAX_SITES_ACC>500]=np.nan ##wierd outlier with 5000 pts
len(OV)
OV['AB_AC'] = OV.MIN_SITES_ABL / OV.MIN_SITES_ACC 
print(np.nanmean(OV.MIN_SITES_ACC))
print(np.nanmean(OV.MAX_SITES_ACC))
print(np.nanmean(OV.MIN_SITES_ABL))
print(np.nanmean(OV.MAX_SITES_ABL))
# Out:
# 11.418478260869565
# 28.091533180778033
# 16.190217391304348
# 18.02888888888889

# %%
pd.set_option('display.max_columns', None)
PTS=(OV.MIN_SITES_ABL+ OV.MIN_SITES_ACC)
PTS.mean()
# Out:
# 27.717032967032967

# %%
PT_DEN=PTS/(OV.ACC_AREA+OV.ABL_AREA)
np.nanmedian(PT_DEN)
# Out:
# 8.771930594029067

# %%
AB_AC[AB_AC==np.inf]=np.nan
AB_AC.dropna()
np.nanmean(AB_AC)
# Out:
# 3.9518839821884395

# %%
OV=OV[OV.NAME=='HELM']
OV
# Out:
#      POLITICAL_UNIT  NAME  WGMS_ID  Year TIME_SYSTEM  BEGIN_PERIOD  \
# 1027             CA  HELM       45  1975         NaN           NaN
# 1028             CA  HELM       45  1976         STR    19750923.0
# 1029             CA  HELM       45  1977         STR    19760927.0
# 1030             CA  HELM       45  1978         STR    19771001.0
# 1031             CA  HELM       45  1979         STR    19780925.0
# 1032             CA  HELM       45  1980         STR    19790925.0
# 1033             CA  HELM       45  1982         STR    19810928.0
# 1034             CA  HELM       45  1983         STR    19821001.0
# 1035             CA  HELM       45  1984         STR    19831004.0
# 1036             CA  HELM       45  1985         STR    19849999.0
# 1037             CA  HELM       45  1986         STR    19859999.0
# 1038             CA  HELM       45  1987         STR    19869999.0
# 1039             CA  HELM       45  1988         STR    19879999.0
# ...

# %%
pd.set_option('display.max_columns', None)
D=data[data.NAME=='PEYTO']
D[data.YEAR>1990.]
# Out:
# /home/pelto/anaconda2/envs/flux/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      POLITICAL_UNIT   NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND    AREA  \
# 8595             CA  PEYTO       57  1991         9999         9999     NaN
# 8596             CA  PEYTO       57  1993         2100         2200   0.100
# 8597             CA  PEYTO       57  1993         2200         2300   0.870
# 8598             CA  PEYTO       57  1993         2300         2400   0.310
# 8599             CA  PEYTO       57  1993         2400         2500   1.450
# 8600             CA  PEYTO       57  1993         2500         2600   2.220
# 8601             CA  PEYTO       57  1993         2600         2700   2.220
# 8602             CA  PEYTO       57  1993         2700         2800   2.130
# ...

# %%
# Out:
# /home/pelto/anaconda2/envs/flux/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      POLITICAL_UNIT   NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND  AREA  \
# 8757             CA  PEYTO       57  2011         9999         9999   NaN
# 8758             CA  PEYTO       57  2012         9999         9999   NaN
# 8759             CA  PEYTO       57  2013         9999         9999   NaN
# 8760             CA  PEYTO       57  2014         9999         9999   NaN
# 8761             CA  PEYTO       57  2015         9999         9999   NaN
# 8762             CA  PEYTO       57  2016         9999         9999   NaN
# 8763             CA  PEYTO       57  2017         9999         9999   NaN
#
#       WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  SUMMER_BALANCE_UNC  \
# 8757             NaN                 NaN             NaN                 NaN
# ...

# %%
pd.set_option('display.max_columns', None)
H=data[data.NAME=='HELM']
H[data.YEAR>2010.]
# Out:
# /home/pelto/anaconda2/envs/flux/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      POLITICAL_UNIT  NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND  AREA  \
# 8090             CA  HELM       45  2011         9999         9999   NaN
# 8091             CA  HELM       45  2012         9999         9999   NaN
# 8092             CA  HELM       45  2013         9999         9999   NaN
# 8093             CA  HELM       45  2015         9999         9999   NaN
# 8094             CA  HELM       45  2016         9999         9999   NaN
# 8095             CA  HELM       45  2017         9999         9999   NaN
#
#       WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  SUMMER_BALANCE_UNC  \
# 8090             NaN                 NaN             NaN                 NaN
# ...

# %%
H=data[data.NAME=='PLACE']
H[data.YEAR>2010.]
# Out:
# /home/pelto/anaconda2/envs/flux/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      POLITICAL_UNIT   NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND  AREA  \
# 8994             CA  PLACE       41  2011         9999         9999   NaN
# 8995             CA  PLACE       41  2012         9999         9999   NaN
# 8996             CA  PLACE       41  2013         9999         9999   NaN
# 8997             CA  PLACE       41  2015         9999         9999   NaN
# 8998             CA  PLACE       41  2016         9999         9999   NaN
# 8999             CA  PLACE       41  2017         9999         9999   NaN
#
#       WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  SUMMER_BALANCE_UNC  \
# 8994             NaN                 NaN             NaN                 NaN
# 8995             NaN                 NaN             NaN                 NaN
# ...
